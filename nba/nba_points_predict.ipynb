# %% [markdown]
# # NBA player points prediction

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
import statsmodels.formula.api as smf
from matplotlib import pyplot as plt

# %% [markdown]
# ## Get data with web scraping

# %%
def get_player_stats(year):
    # URL page we will scraping (see image above)
    url = "https://www.basketball-reference.com/leagues/NBA_{}_totals.html".format(year)
    # this is the HTML from the given URL
    html = urlopen(url)
    soup = BeautifulSoup(html, features="html.parser")

    # use findALL() to get the column headers
    soup.findAll('tr', limit=2)
    # use getText()to extract the text we need into a list
    headers = [th.getText() for th in 
        soup.findAll('tr', limit=2)[0].findAll('th')]
    # exclude the first column as we will not need the 
    # ranking order from Basketball Reference for the analysis
    headers = headers[1:]

    # avoid the first header row
    rows = soup.findAll('tr')[1:]

    player_stats = [[td.getText() for td 
        in rows[i].findAll('td')]
        for i in range(len(rows))]

    # Create DataFrame
    return pd.DataFrame(player_stats, columns=headers)

# %% [markdown]
# * Pos: Position.
# * Age: Player age.
# * G: Games.
# * GS: Games started
# * MP: Minutes played.
# * FG (3P + 2P): Field goals.
# * FGA (3PA + 2PA): Field goal attempts.
# * FG%: Field goal percentage.
# * 3P: 3 points field goals.
# * 3PA: 3 point field goal attempts.
# * 3P%: FG% on 3 points FGA’s (field goal attempts).
# * 2P: 2 points field goals.
# * 2PA: 2 point field goal attempts.
# * 2P%: FG% on 2 points FGA’s (field goal attempts).
# * FT:Free Throwns.
# * FTA:Free Thrown Attempts.
# * FT%: Free Throw Percentage.
# * ORB: Offensive Rebounds.
# * DRB: Defensive Rebounds.
# * TRB: Total Rebounds
# * AST: Assists.
# * STL: Steals.
# * BLK: Blocks.
# * TOV:Turnovers.
# * PF: Personal Fouls.
# * PTS: Points.

# %%
original_data2019 = get_player_stats(2019)

# %%
original_data2020 = get_player_stats(2020)

# %%
data2019 = original_data2019.copy()
data2019
# Out:
#            Player Pos Age   Tm   G  GS    MP   FG  FGA   FG%  ...   FT%  ORB  \
# 0    Álex Abrines  SG  25  OKC  31   2   588   56  157  .357  ...  .923    5
# 1      Quincy Acy  PF  28  PHO  10   0   123    4   18  .222  ...  .700    3
# 2    Jaylen Adams  PG  22  ATL  34   1   428   38  110  .345  ...  .778   11
# 3    Steven Adams   C  25  OKC  80  80  2669  481  809  .595  ...  .500  391
# 4     Bam Adebayo   C  21  MIA  82  28  1913  280  486  .576  ...  .735  165
# ..            ...  ..  ..  ...  ..  ..   ...  ...  ...   ...  ...   ...  ...
# 729  Tyler Zeller   C  29  MEM   4   1    82   16   28  .571  ...  .778    9
# 730    Ante Žižić   C  22  CLE  59  25  1082  183  331  .553  ...  .705  108
# 731   Ivica Zubac   C  21  TOT  59  37  1040  212  379  .559  ...  .802  115
# 732   Ivica Zubac   C  21  LAL  33  12   516  112  193  .580  ...  .864   54
# 733   Ivica Zubac   C  21  LAC  26  25   524  100  186  .538  ...  .733   61
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 0     43   48   20   17   6   14   53   165
# 1     22   25    8    1   4    4   24    17
# 2     49   60   65   14   5   28   45   108
# 3    369  760  124  117  76  135  204  1108
# 4    432  597  184   71  65  121  203   729
# ..   ...  ...  ...  ...  ..  ...  ...   ...
# 729    9   18    3    1   3    4   16    46
# 730  212  320   53   13  22   61  113   459
# 731  247  362   63   14  51   70  137   525
# 732  108  162   25    4  27   33   73   281
# 733  139  200   38   10  24   37   64   244
#
# [734 rows x 29 columns]

# %%
data2020 = original_data2020.copy()
data2020
# Out:
#                        Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  \
# 0                Steven Adams   C  26  OKC  63  63  1680  283   478  .592
# 1                 Bam Adebayo  PF  22  MIA  72  72  2417  440   790  .557
# 2           LaMarcus Aldridge   C  34  SAS  53  53  1754  391   793  .493
# 3              Kyle Alexander   C  23  MIA   2   0    13    1     2  .500
# 4    Nickeil Alexander-Walker  SG  21  NOP  47   1   591   98   266  .368
# ..                        ...  ..  ..  ...  ..  ..   ...  ...   ...   ...
# 672                Trae Young  PG  21  ATL  60  60  2120  546  1249  .437
# 673               Cody Zeller   C  27  CHO  58  39  1341  251   479  .524
# 674              Tyler Zeller   C  30  SAS   2   0     4    1     4  .250
# 675                Ante Žižić   C  23  CLE  22   0   221   41    72  .569
# 676               Ivica Zubac   C  22  LAC  72  70  1326  236   385  .613
#
#      ...   FT%  ORB  DRB  TRB  AST STL BLK  TOV   PF   PTS
# 0    ...  .582  207  376  583  146  51  67   94  122   684
# 1    ...  .691  176  559  735  368  82  93  204  182  1146
# 2    ...  .827  103  289  392  129  36  87   74  128  1001
# 3    ...          2    1    3    0   0   0    1    1     2
# 4    ...  .676    9   75   84   89  17   8   54   57   267
# ..   ...   ...  ...  ...  ...  ...  ..  ..  ...  ...   ...
# 672  ...  .860   32  223  255  560  65   8  289  104  1778
# 673  ...  .682  160  251  411   88  40  25   75  140   642
# 674  ...          3    1    4    0   0   0    0    0     2
# 675  ...  .737   18   48   66    6   7   5   10   27    96
# 676  ...  .747  197  346  543   82  16  66   61  168   596
#
# [677 rows x 29 columns]

# %% [markdown]
# ## Data Wrangling

# %%
def crossjoin(df1, df2):
    for index, row in df1.iterrows():
        player = df2.loc[df2['Player'] == row['Player']]
        if(not player.empty):
            continue
        else:
            df1.drop(index, inplace=True)
            df2.drop(player.index, inplace=True)
            
    return (df1, df2)

# %%
data2020, data2019 = crossjoin(data2020, data2019)
data2019, data2020 = crossjoin(data2019, data2020)

# %%
data2019.columns
# Out:
# Index(['Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P',
#        '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB',
#        'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
data2019 = data2019[['Player', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P',
       '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB',
       'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].apply(lambda x: pd.to_numeric(x.astype(str).str.replace(',',''), errors='ignore'))
data2020 = data2020[['Player','G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P',
       '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB',
       'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']].apply(lambda x: pd.to_numeric(x.astype(str).str.replace(',',''), errors='ignore'))

# %% [markdown]
# ### Create new column with total field goals attempts

# %%
data2019['TA'] = data2019['FGA'] + data2019['FTA'] 
data2020['TA'] = data2020['FGA'] + data2020['FTA']

# %% [markdown]
# ## Correlation

# %%
corr2019 = data2019.corr()
corr2019.style.format(precision=3).background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_a7ded_row0_col0, #T_a7ded_row1_col1, #T_a7ded_row2_col2, #T_a7ded_row3_col3, #T_a7ded_row4_col4, #T_a7ded_row5_col5, #T_a7ded_row6_col6, #T_a7ded_row7_col7, #T_a7ded_row8_col8, #T_a7ded_row9_col9, #T_a7ded_row10_col10, #T_a7ded_row11_col11, #T_a7ded_row12_col12, #T_a7ded_row13_col13, #T_a7ded_row14_col14, #T_a7ded_row15_col15, #T_a7ded_row16_col16, #T_a7ded_row17_col17, #T_a7ded_row18_col18, #T_a7ded_row19_col19, #T_a7ded_row20_col20, #T_a7ded_row21_col21, #T_a7ded_row22_col22, #T_a7ded_row23_col23, #T_a7ded_row24_col24, #T_a7ded_row25_col25 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a7ded_row0_col1 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_a7ded_row0_col2, #T_a7ded_row13_col9 {
#   background-color: #e16751;
#   color: #f1f1f1;
# }
# #T_a7ded_row0_col3, #T_a7ded_row0_col4, #T_a7ded_row13_col2, #T_a7ded_row13_col18, #T_a7ded_row22_col1 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_a7ded_row0_col5, #T_a7ded_row11_col18, #T_a7ded_row14_col5 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_a7ded_row0_col6, #T_a7ded_row21_col23, #T_a7ded_row22_col0 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_a7ded_row0_col7 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_a7ded_row0_col8, #T_a7ded_row13_col11 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_a7ded_row0_col9, #T_a7ded_row1_col14, #T_a7ded_row9_col19, #T_a7ded_row17_col1, #T_a7ded_row20_col7, #T_a7ded_row23_col14 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_a7ded_row0_col10, #T_a7ded_row6_col2, #T_a7ded_row18_col13, #T_a7ded_row20_col17 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_a7ded_row0_col11 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_a7ded_row0_col12, #T_a7ded_row1_col5, #T_a7ded_row3_col11, #T_a7ded_row3_col15, #T_a7ded_row4_col8, #T_a7ded_row12_col9, #T_a7ded_row17_col12, #T_a7ded_row21_col12 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_a7ded_row0_col13, #T_a7ded_row24_col21 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_a7ded_row0_col14, #T_a7ded_row13_col16 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_a7ded_row0_col15, #T_a7ded_row19_col8, #T_a7ded_row20_col5, #T_a7ded_row20_col8, #T_a7ded_row22_col11 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_a7ded_row0_col16 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_a7ded_row0_col17, #T_a7ded_row1_col18, #T_a7ded_row10_col16, #T_a7ded_row11_col12, #T_a7ded_row19_col14 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_a7ded_row0_col18, #T_a7ded_row1_col20, #T_a7ded_row1_col23, #T_a7ded_row9_col1, #T_a7ded_row18_col22, #T_a7ded_row19_col9, #T_a7ded_row20_col9, #T_a7ded_row24_col0 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_a7ded_row0_col19, #T_a7ded_row1_col0, #T_a7ded_row4_col16, #T_a7ded_row6_col20, #T_a7ded_row7_col0, #T_a7ded_row14_col6, #T_a7ded_row23_col19 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_a7ded_row0_col20, #T_a7ded_row0_col24, #T_a7ded_row0_col25, #T_a7ded_row20_col0 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_a7ded_row0_col21, #T_a7ded_row1_col21, #T_a7ded_row10_col7, #T_a7ded_row16_col14, #T_a7ded_row19_col17, #T_a7ded_row23_col6 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_a7ded_row0_col22, #T_a7ded_row3_col16, #T_a7ded_row18_col0 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_a7ded_row0_col23, #T_a7ded_row9_col18 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_a7ded_row1_col2, #T_a7ded_row16_col17, #T_a7ded_row22_col2 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_a7ded_row1_col3, #T_a7ded_row3_col1, #T_a7ded_row17_col14 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_a7ded_row1_col4, #T_a7ded_row2_col14, #T_a7ded_row4_col1, #T_a7ded_row4_col20, #T_a7ded_row7_col4, #T_a7ded_row14_col18, #T_a7ded_row17_col2, #T_a7ded_row22_col17, #T_a7ded_row24_col1, #T_a7ded_row24_col6 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_a7ded_row1_col6, #T_a7ded_row1_col19, #T_a7ded_row9_col0, #T_a7ded_row13_col1 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_a7ded_row1_col7, #T_a7ded_row20_col6, #T_a7ded_row22_col6 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_a7ded_row1_col8, #T_a7ded_row5_col14, #T_a7ded_row11_col9 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_a7ded_row1_col9, #T_a7ded_row19_col20, #T_a7ded_row20_col3, #T_a7ded_row23_col10 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_a7ded_row1_col10, #T_a7ded_row3_col19, #T_a7ded_row3_col20, #T_a7ded_row17_col22, #T_a7ded_row17_col24, #T_a7ded_row18_col3, #T_a7ded_row20_col25, #T_a7ded_row24_col23, #T_a7ded_row25_col18 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_a7ded_row1_col11, #T_a7ded_row22_col15 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_a7ded_row1_col12 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_a7ded_row1_col13, #T_a7ded_row7_col3, #T_a7ded_row9_col21, #T_a7ded_row16_col23, #T_a7ded_row18_col4, #T_a7ded_row20_col18 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_a7ded_row1_col15, #T_a7ded_row3_col8, #T_a7ded_row19_col15 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_a7ded_row1_col16, #T_a7ded_row23_col7 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_a7ded_row1_col17, #T_a7ded_row3_col0, #T_a7ded_row3_col6, #T_a7ded_row4_col0, #T_a7ded_row4_col18, #T_a7ded_row10_col1, #T_a7ded_row10_col19, #T_a7ded_row16_col9, #T_a7ded_row17_col4, #T_a7ded_row18_col2, #T_a7ded_row20_col10 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_a7ded_row1_col22, #T_a7ded_row10_col23, #T_a7ded_row13_col17, #T_a7ded_row19_col10, #T_a7ded_row21_col17 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_a7ded_row1_col24, #T_a7ded_row1_col25, #T_a7ded_row2_col6, #T_a7ded_row19_col4, #T_a7ded_row19_col25, #T_a7ded_row20_col4, #T_a7ded_row20_col22, #T_a7ded_row23_col3, #T_a7ded_row23_col9, #T_a7ded_row24_col18, #T_a7ded_row25_col1, #T_a7ded_row25_col20 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_a7ded_row2_col0, #T_a7ded_row2_col23, #T_a7ded_row13_col3, #T_a7ded_row19_col22, #T_a7ded_row22_col14, #T_a7ded_row22_col19 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_a7ded_row2_col1, #T_a7ded_row4_col7, #T_a7ded_row5_col11, #T_a7ded_row11_col5, #T_a7ded_row20_col2 {
#   background-color: #eb7d62;
#   color: #f1f1f1;
# }
# #T_a7ded_row2_col3, #T_a7ded_row3_col22, #T_a7ded_row4_col9, #T_a7ded_row4_col22, #T_a7ded_row14_col24 {
#   background-color: #d75445;
#   color: #f1f1f1;
# }
# #T_a7ded_row2_col4, #T_a7ded_row9_col24, #T_a7ded_row9_col25 {
#   background-color: #d55042;
#   color: #f1f1f1;
# }
# #T_a7ded_row2_col5, #T_a7ded_row13_col5, #T_a7ded_row24_col15 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_a7ded_row2_col7, #T_a7ded_row2_col18, #T_a7ded_row4_col19, #T_a7ded_row14_col17, #T_a7ded_row16_col21, #T_a7ded_row25_col17, #T_a7ded_row25_col19 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_a7ded_row2_col8, #T_a7ded_row2_col15, #T_a7ded_row13_col15, #T_a7ded_row25_col5 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_a7ded_row2_col9, #T_a7ded_row2_col22 {
#   background-color: #e97a5f;
#   color: #f1f1f1;
# }
# #T_a7ded_row2_col10, #T_a7ded_row9_col17, #T_a7ded_row18_col9, #T_a7ded_row23_col0 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_a7ded_row2_col11 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_a7ded_row2_col12, #T_a7ded_row25_col11 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_a7ded_row2_col13, #T_a7ded_row4_col23, #T_a7ded_row17_col25, #T_a7ded_row18_col14, #T_a7ded_row22_col20, #T_a7ded_row24_col20, #T_a7ded_row25_col23 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_a7ded_row2_col16, #T_a7ded_row13_col20, #T_a7ded_row19_col6, #T_a7ded_row23_col13 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_a7ded_row2_col17, #T_a7ded_row17_col23 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_a7ded_row2_col19, #T_a7ded_row19_col3, #T_a7ded_row19_col24, #T_a7ded_row20_col23, #T_a7ded_row20_col24, #T_a7ded_row22_col18, #T_a7ded_row22_col23 {
#   background-color: #f6a283;
#   color: #0000

# %%
corr2019[corr2019['PTS'] > 0.7]['PTS']
# Out:
# G      0.734652
# GS     0.792749
# MP     0.906744
# FG     0.992596
# FGA    0.989421
# 3P     0.739717
# 3PA    0.755715
# 2P     0.919859
# 2PA    0.937531
# FT     0.921784
# FTA    0.914765
# DRB    0.786505
# TRB    0.744496
# AST    0.774326
# STL    0.772120
# TOV    0.909945
# PF     0.767228
# PTS    1.000000
# TA     0.995355
# Name: PTS, dtype: float64

# %% [markdown]
# ### Most correlated vars

# %%
corr_columns = list(corr2019[corr2019['PTS'] > 0.7]['PTS'].keys())
corr_columns.append('Player')
data2019 = data2019[corr_columns]

# %%
data2019
# Out:
#       G  GS    MP   FG   FGA  3P  3PA   2P   2PA   FT  FTA  DRB  TRB  AST  \
# 3    80  80  2669  481   809   0    2  481   807  146  292  369  760  124
# 4    82  28  1913  280   486   3   15  277   471  166  226  432  597  184
# 7    81  81  2687  684  1319  10   42  674  1277  349  412  493  744  194
# 9    38   2   416   67   178  32   99   35    79   45   60   20   23   25
# 10   80  80  2096  335   568   6   45  329   523  197  278  481  672  110
# ..   ..  ..   ...  ...   ...  ..  ...  ...   ...  ...  ...  ...  ...  ...
# 729   4   1    82   16    28   0    0   16    28   14   18    9   18    3
# 730  59  25  1082  183   331   0    0  183   331   93  132  212  320   53
# 731  59  37  1040  212   379   0    0  212   379  101  126  247  362   63
# 732  33  12   516  112   193   0    0  112   193   57   66  108  162   25
# 733  26  25   524  100   186   0    0  100   186   44   60  139  200   38
#
#      STL  TOV   PF   PTS    TA             Player
# 3    117  135  204  1108  1101       Steven Adams
# 4     71  121  203   729   712        Bam Adebayo
# 7     43  144  179  1727  1731  LaMarcus Aldridge
# 9      6   33   47   211   238      Grayson Allen
# 10    43  103  184   873   846      Jarrett Allen
# ..   ...  ...  ...   ...   ...                ...
# 729    1    4   16    46    46       Tyler Zeller
# 730   13   61  113   459   463         Ante Žižić
# 731   14   70  137   525   505        Ivica Zubac
# 732    4   33   73   281   259        Ivica Zubac
# 733   10   37   64   244   246        Ivica Zubac
#
# [528 rows x 20 columns]

# %%
corr2019 = data2019.corr()
corr2019.style.format(precision=3).background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_80a7f_row0_col0, #T_80a7f_row1_col1, #T_80a7f_row2_col2, #T_80a7f_row3_col3, #T_80a7f_row4_col4, #T_80a7f_row5_col5, #T_80a7f_row6_col6, #T_80a7f_row7_col7, #T_80a7f_row8_col8, #T_80a7f_row9_col9, #T_80a7f_row10_col10, #T_80a7f_row11_col11, #T_80a7f_row12_col12, #T_80a7f_row13_col13, #T_80a7f_row14_col14, #T_80a7f_row15_col15, #T_80a7f_row16_col16, #T_80a7f_row17_col17, #T_80a7f_row18_col18 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_80a7f_row0_col1, #T_80a7f_row10_col0, #T_80a7f_row12_col17 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_80a7f_row0_col2, #T_80a7f_row2_col15 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_80a7f_row0_col3 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_80a7f_row0_col4 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_80a7f_row0_col5, #T_80a7f_row1_col5, #T_80a7f_row1_col6, #T_80a7f_row3_col14, #T_80a7f_row8_col2 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_80a7f_row0_col6, #T_80a7f_row1_col16, #T_80a7f_row9_col13 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_80a7f_row0_col7 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_80a7f_row0_col8 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_80a7f_row0_col9, #T_80a7f_row5_col17 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_80a7f_row0_col10, #T_80a7f_row0_col15 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_80a7f_row0_col11, #T_80a7f_row1_col8, #T_80a7f_row2_col10, #T_80a7f_row17_col16 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_80a7f_row0_col12, #T_80a7f_row3_col5, #T_80a7f_row3_col16 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_80a7f_row0_col13 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_80a7f_row0_col14, #T_80a7f_row8_col6, #T_80a7f_row12_col9, #T_80a7f_row13_col4 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_80a7f_row0_col16, #T_80a7f_row8_col9 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_80a7f_row0_col17, #T_80a7f_row5_col1, #T_80a7f_row5_col2, #T_80a7f_row5_col3, #T_80a7f_row5_col7, #T_80a7f_row5_col8, #T_80a7f_row5_col9, #T_80a7f_row5_col10, #T_80a7f_row5_col11, #T_80a7f_row5_col12, #T_80a7f_row5_col14, #T_80a7f_row5_col15, #T_80a7f_row5_col16, #T_80a7f_row5_col18, #T_80a7f_row9_col0, #T_80a7f_row12_col4, #T_80a7f_row12_col5, #T_80a7f_row12_col6, #T_80a7f_row12_col13 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_80a7f_row0_col18 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_80a7f_row1_col0, #T_80a7f_row6_col0, #T_80a7f_row6_col2 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_80a7f_row1_col2 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_80a7f_row1_col3, #T_80a7f_row7_col1 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_80a7f_row1_col4 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_80a7f_row1_col7 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_80a7f_row1_col9, #T_80a7f_row12_col0 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_80a7f_row1_col10, #T_80a7f_row1_col15, #T_80a7f_row7_col2, #T_80a7f_row16_col10, #T_80a7f_row18_col0 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_80a7f_row1_col11, #T_80a7f_row17_col13 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_80a7f_row1_col12 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_80a7f_row1_col13, #T_80a7f_row11_col1 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_80a7f_row1_col14, #T_80a7f_row16_col3 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_80a7f_row1_col17, #T_80a7f_row1_col18, #T_80a7f_row15_col0 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_80a7f_row2_col0, #T_80a7f_row4_col10, #T_80a7f_row10_col18, #T_80a7f_row16_col12 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_80a7f_row2_col1 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_80a7f_row2_col3, #T_80a7f_row4_col9 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_80a7f_row2_col4 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_80a7f_row2_col5 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_80a7f_row2_col6, #T_80a7f_row10_col11 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_80a7f_row2_col7, #T_80a7f_row3_col11, #T_80a7f_row15_col9 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_80a7f_row2_col8, #T_80a7f_row8_col11 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_80a7f_row2_col9 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_80a7f_row2_col11, #T_80a7f_row7_col9, #T_80a7f_row10_col17, #T_80a7f_row15_col4 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_80a7f_row2_col12, #T_80a7f_row10_col3, #T_80a7f_row15_col17, #T_80a7f_row16_col0 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_80a7f_row2_col13, #T_80a7f_row4_col1 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_80a7f_row2_col14, #T_80a7f_row11_col16, #T_80a7f_row15_col11 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_80a7f_row2_col16, #T_80a7f_row9_col7 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_80a7f_row2_col17, #T_80a7f_row7_col4, #T_80a7f_row9_col3, #T_80a7f_row17_col11 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_80a7f_row2_col18 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_80a7f_row3_col0, #T_80a7f_row7_col13, #T_80a7f_row9_col5 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_80a7f_row3_col1, #T_80a7f_row4_col16, #T_80a7f_row18_col16 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_80a7f_row3_col2, #T_80a7f_row4_col5 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_80a7f_row3_col4 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_80a7f_row3_col6, #T_80a7f_row9_col12 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_80a7f_row3_col7 {
#   background-color: #d1493f;
#   color: #f1f1f1;
# }
# #T_80a7f_row3_col8 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_80a7f_row3_col9 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_80a7f_row3_col10, #T_80a7f_row8_col10 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_80a7f_row3_col12 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_80a7f_row3_col13 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_80a7f_row3_col15, #T_80a7f_row4_col15, #T_80a7f_row9_col8 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_80a7f_row3_col17, #T_80a7f_row4_col18, #T_80a7f_row10_col9 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_80a7f_row3_col18, #T_80a7f_row4_col3 {
#   background-color: #c53334;
#   color: #f1f1f1;
# }
# #T_80a7f_row4_col0, #T_80a7f_row11_col3, #T_80a7f_row11_col15 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_80a7f_row4_col2, #T_80a7f_row7_col18, #T_80a7f_row13_col15 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_80a7f_row4_col6, #T_80a7f_row7_col17, #T_80a7f_row15_col3, #T_80a7f_row16_col11 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_80a7f_row4_col7 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_80a7f_row4_col8 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_80a7f_row4_col11 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_80a7f_row4_col12 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_80a7f_row4_col13, #T_80a7f_row16_col2, #T_80a7f_row16_col7, #T_80a7f_row18_col13 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_80a7f_row4_col14 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_80a7f_row4_col17 {
#   background-color: #c32e31;
#   color: #f1f1f1;
# }
# #T_80a7f_row5_col0, #T_80a7f_row6_col12 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_80a7f_row5_col4, #T_80a7f_row7_col0, #T_80a7f_row10_col1 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_80a7f_row5_col6, #T_80a7f_row6_col5 {
#   background-color: #b8122a;
#   color: #f1f1f1;
# }
# #T_80a7f_row5_col13, #T_80a7f_row11_col4, #T_80a7f_row16_col13 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_80a7f_row6_col1, #T_80a7f_row13_col0 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_80a7f_row6_col3 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_80a7f_row6_col4, #T_80a7f_row11_col0 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_80a7f_row6_col7, #T_80a7f_row6_col16 {

# %% [markdown]
# ## Build model

# %% [markdown]
# ### Sum data of a player
# If player was in several teams in the season we maybe should sum his data in one row, for represent the entire season in one row per player.

# %%
data2019 = data2019.groupby('Player', as_index=False)[corr_columns].sum()

# %%
data2019
# Out:
#               Player   G  GS    MP   FG   FGA   3P  3PA   2P  2PA   FT  FTA  \
# 0       Aaron Gordon  78  78  2633  470  1046  121  347  349  699  185  253
# 1      Aaron Holiday  50   0   646  105   262   43  127   62  135   41   50
# 2        Abdel Nader  61   1   694   91   215   32  100   59  115   27   36
# 3         Al Horford  68  68  1973  387   723   73  203  314  520   78   95
# 4    Al-Farouq Aminu  81  81  2292  257   593   96  280  161  313  150  173
# ..               ...  ..  ..   ...  ...   ...  ...  ...  ...  ...  ...  ...
# 395     Yogi Ferrell  71   3  1067  153   352   54  149   99  203   60   67
# 396    Yuta Watanabe  15   0   174   15    51    2   16   13   35    7   10
# 397     Zach Collins  77   0  1356  189   400   40  121  149  279   94  126
# 398      Zach LaVine  63  62  2171  530  1135  120  321  410  814  312  375
# 399     Zhaire Smith   6   2   111   14    34    6   16    8   18    6    8
#
#      DRB  TRB  AST  STL  TOV   PF   PTS    TA
# 0    445  574  289   57  162  172  1246  1299
# 1     62   67   87   21   40   71   294   312
# 2    102  116   20   20   26   68   241   251
# 3    338  458  283   59  102  126   925   818
# 4    498  610  104   68   72  143   760   766
# ..   ...  ...  ...  ...  ...  ...   ...   ...
# 395   96  109  137   36   40   64   420   419
# 396   27   31    8    4    6   11    39    61
# 397  215  324   71   25   77  174   512   526
# 398  254  294  283   60  215  140  1492  1510
# 399   10   13   10    2    6    8    40    42
#
# [400 rows x 20 columns]

# %%
data2020 = data2020.groupby('Player', as_index=False)[corr_columns].sum()

# %% [markdown]
# ### Model with total attempts

# %%
lm_TA = smf.ols(formula='PTS~TA', data=data2019).fit()
lm_TA.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    PTS   R-squared:                       0.990
# Model:                            OLS   Adj. R-squared:                  0.990
# Method:                 Least Squares   F-statistic:                 4.056e+04
# Date:                Mon, 27 Dec 2021   Prob (F-statistic):               0.00
# Time:                        16:52:54   Log-Likelihood:                -2175.6
# No. Observations:                 400   AIC:                             4355.
# Df Residuals:                     398   BIC:                             4363.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -2.0587      4.508     -0.457      0.648     -10.922       6.805
# TA             0.9948      0.005    201.388      0.000       0.985       1.004
# ==============================================================================
# Omnibus:                       32.340   Durbin-Watson:                   1.876
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              118.754
# Skew:                           0.209   Prob(JB):                     1.63e-26
# Kurtosis:                       5.636   Cond. No.                     1.47e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.47e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
data2020['PTS_pred_TA'] = lm_TA.params[0] + lm_TA.params[1] * data2019['TA']

# %% [markdown]
# ### Model with minutes played

# %%
lm_MP = smf.ols(formula='PTS~MP', data=data2019).fit()
lm_MP.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    PTS   R-squared:                       0.803
# Model:                            OLS   Adj. R-squared:                  0.802
# Method:                 Least Squares   F-statistic:                     1618.
# Date:                Mon, 27 Dec 2021   Prob (F-statistic):          2.71e-142
# Time:                        16:52:54   Log-Likelihood:                -2777.9
# No. Observations:                 400   AIC:                             5560.
# Df Residuals:                     398   BIC:                             5568.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -58.2706     22.890     -2.546      0.011    -103.271     -13.270
# MP             0.4954      0.012     40.224      0.000       0.471       0.520
# ==============================================================================
# Omnibus:                       91.333   Durbin-Watson:                   2.022
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              355.914
# Skew:                           0.954   Prob(JB):                     5.18e-78
# Kurtosis:                       7.209   Cond. No.                     3.38e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.38e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
data2020['PTS_pred_MP'] = lm_MP.params[0] + lm_MP.params[1] * data2019['MP']

# %% [markdown]
# ### Model with assits

# %%
lm_AST = smf.ols(formula='PTS~AST', data=data2019).fit()
lm_AST.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    PTS   R-squared:                       0.552
# Model:                            OLS   Adj. R-squared:                  0.551
# Method:                 Least Squares   F-statistic:                     491.0
# Date:                Mon, 27 Dec 2021   Prob (F-statistic):           1.90e-71
# Time:                        16:52:54   Log-Likelihood:                -2941.6
# No. Observations:                 400   AIC:                             5887.
# Df Residuals:                     398   BIC:                             5895.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    264.8252     27.646      9.579      0.000     210.475     319.175
# AST            2.9097      0.131     22.158      0.000       2.652       3.168
# ==============================================================================
# Omnibus:                       49.213   Durbin-Watson:                   2.117
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               91.257
# Skew:                           0.714   Prob(JB):                     1.53e-20
# Kurtosis:                       4.853   Cond. No.                         307.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
data2020['PTS_pred_AST'] = lm_AST.params[0] + lm_AST.params[1] * data2019['AST']

# %% [markdown]
# ### Model with steals

# %%
lm_STL = smf.ols(formula='PTS~STL', data=data2019).fit()
lm_STL.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    PTS   R-squared:                       0.565
# Model:                            OLS   Adj. R-squared:                  0.564
# Method:                 Least Squares   F-statistic:                     517.5
# Date:                Mon, 27 Dec 2021   Prob (F-statistic):           5.40e-74
# Time:                        16:52:54   Log-Likelihood:                -2935.7
# No. Observations:                 400   AIC:                             5875.
# Df Residuals:                     398   BIC:                             5883.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    179.3376     29.909      5.996      0.000     120.537     238.138
# STL           10.7798      0.474     22.748      0.000       9.848      11.711
# ==============================================================================
# Omnibus:                       78.102   Durbin-Watson:                   2.087
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              184.943
# Skew:                           0.978   Prob(JB):                     6.92e-41
# Kurtosis:                       5.696   Cond. No.                         101.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
data2020['PTS_pred_STL'] = lm_STL.params[0] + lm_STL.params[1] * data2019['STL']

# %%
data2020
# Out:
#               Player   G  GS    MP   FG   FGA   3P  3PA   2P  2PA  ...  AST  \
# 0       Aaron Gordon  62  62  2017  335   767   73  237  262  530  ...  228
# 1      Aaron Holiday  66  33  1617  233   563   87  221  146  342  ...  225
# 2        Abdel Nader  55   6   867  123   263   48  128   75  135  ...   38
# 3         Al Horford  67  61  2025  319   709   99  283  220  426  ...  270
# 4    Al-Farouq Aminu  18   2   380   25    86    9   36   16   50  ...   21
# ..               ...  ..  ..   ...  ...   ...  ...  ...  ...  ...  ...  ...
# 395     Yogi Ferrell  50   0   530   79   188   24   79   55  109  ...   69
# 396    Yuta Watanabe  18   0   105   15    34    3    8   12   26  ...    5
# 397     Zach Collins  11  11   290   32    68    7   19   25   49  ...   16
# 398      Zach LaVine  60  60  2085  539  1199  184  484  355  715  ...  254
# 399     Zhaire Smith   7   0    32    3    11    0    3    3    8  ...    2
#
#      STL  TOV   PF   PTS    TA  PTS_pred_TA  PTS_pred_MP  PTS_pred_AST  \
# 0     51  100  125   894   991  1290.145920  1246.074479   1105.738512
# 1     55   88  120   627   650   308.309127   261.747183    517.972109
# 2     23   43   78   345   329   247.628231   285.525597    323.019887
# 3     52   80  142   798   789   811.662134   919.121275   1088.280104
# 4     18   17   27    78   115   759.934157  1077.148657    567.437599
# ..   ...  ...  ...   ...   ...          ...          ...           ...
# 395   18   28   38   218   230   414.749387   470.303696    663.458843
# 396    5    2    9    36    42    58.622161    27.926104    288.103071
# 397    5   14   36    77    76   521.189648   613.469568    471.416355
# 398   88  206  131  1530  1533  1500.042134  1017.207236   1088.280104
# 399    3    2    4     8    15    39.721554    -3.283066    293.922540
#
#      PTS_pred_STL
# 0      793.784825
# 1      405.712891
# 2      394.933115
# 3      815.344377
# 4      912.362361
# ..            ...
# 395    567.409531
# 396    222.456700
# 397    448.831995
# 398    826.124153
# 399    200.897148
#
# [400 rows x 24 columns]

# %%
def percentage_change(col1,col2):
    return abs(((col2 - col1) / col1) * 100)

# %%
data2020['change_pred_TA'] = percentage_change(data2020['PTS'], data2020['PTS_pred_TA'])
data2020['change_pred_MP'] = percentage_change(data2020['PTS'], data2020['PTS_pred_MP'])
data2020['change_pred_AST'] = percentage_change(data2020['PTS'], data2020['PTS_pred_AST'])
data2020['change_pred_STL'] = percentage_change(data2020['PTS'], data2020['PTS_pred_STL'])

# %%
data2020.columns
# Out:
# Index(['Player', 'G', 'GS', 'MP', 'FG', 'FGA', '3P', '3PA', '2P', '2PA', 'FT',
#        'FTA', 'DRB', 'TRB', 'AST', 'STL', 'TOV', 'PF', 'PTS', 'TA',
#        'PTS_pred_TA', 'PTS_pred_MP', 'PTS_pred_AST', 'PTS_pred_STL',
#        'change_pred_TA', 'change_pred_MP', 'change_pred_AST',
#        'change_pred_STL'],
#       dtype='object')

# %%
def min_name_dict(test_dict):
    min_value = min(test_dict.values())
    return [key for key in test_dict if test_dict[key] == min_value][0]

data2020['best'] = data2020.apply(lambda row: min_name_dict(row[['change_pred_TA', 'change_pred_MP', 'change_pred_AST',
       'change_pred_STL']].to_dict()).split('_')[-1], axis=1)

# %%
data2020['best'].value_counts()
# Out:
# TA     132
# AST    121
# MP      74
# STL     73
# Name: best, dtype: int64
